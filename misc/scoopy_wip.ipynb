# %%
from scoopy import search_news
import pandas as pd

results = search_news('Artificial Intelligence')

pd.DataFrame(results)
# Out:
#                          article_id  \
# 0  cf1be26bf342a682c378588b33d673d6
# 1  1150d9acab437958170591236e765871
# 2  49f22ee144264a49acf97cf06e0e674c
# 3  55a53217136e81f4d2d148c9e440d6b9
# 4  14e655d6a994df7ced7e5297f7c33d72
# 5  ac7ba53ee68566458e4e90b69740d8bd
# 6  d1460aa05676599990146e44e16cf18e
# 7  50ed6fd35db4c24482445f6c723015f2
# 8  5a706dfc4c4dad0a827580cd4728d14a
# 9  416ed2eee989b9e69b41d9618cd8b423
#
#                                                title  \
# 0  KPK Siap Hadapi Jika Hasto Kristiyanto Kembali...
# 1  Penjawat awam selesa jadi cabaran pelaksanaan ...
# 2                             性侵18岁怀孕弟媳 油棕园工人判监7年打两鞭
# 3  В «Кабилии» заявили, что Игнатьев оставил хоро...
# 4  Ulagači u ovaj oblik imovine najveći su dobi...
# 5  Ibex 35: ArcelorMittal (-3,32%) y Ferrovial (-...
# 6  PepsiCo (NASDAQ:PEP) Stock Unloaded Rep. Julie...
# 7  ボルボ XC90が大幅改良を受けて日本市場に導入開始!完全電動化の計画修正で大注目(...
# 8  Leak reveals display sizes of Apple's first-ge...
# ...
